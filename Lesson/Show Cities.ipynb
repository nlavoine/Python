# %% [markdown]
# ## Display file data

# %%
import pandas
data_frame = pandas.read_csv('villes_france.csv', header=None, sep=',', skipinitialspace=False)
# print(data_frame)
data_frame.head()
# Out:
#    0  1                      2                      3                      4   \
# 0   1  1                   ozan                   OZAN                   ozan
# 1   2  1  cormoranche-sur-saone  CORMORANCHE-SUR-SAONE  cormoranche sur saone
# 2   3  1              plagne-01                 PLAGNE                 plagne
# 3   4  1                tossiat                TOSSIAT                tossiat
# 4   5  1               pouillat               POUILLAT               pouillat
#
#                       5          6           7      8    9   ...   17     18  \
# 0                   Ozan       O250         OSN  01190  284  ...   93   6.60
# 1  Cormoranche-sur-Saône  C65652625  KRMRNXSRSN  01290  123  ...  107   9.85
# 2                 Plagne       P425        PLKN  01130  298  ...   20   6.20
# 3                Tossiat       T230         TST  01250  422  ...  138  10.17
# 4               Pouillat       P430         PLT  01250  309  ...   14   6.23
#
# ...

# %% [markdown]
# ## Sort by people

# %%
data_frame2 = data_frame.sort_values(data_frame.columns[15], ascending=False)
data_frame2.head()
# Out:
#           0   1          2          3          4          5     6     7   \
# 30437  30438  75      paris      PARIS      paris      Paris  P620   PRS
# 4439    4440  13  marseille  MARSEILLE  marseille  Marseille  M624  MRSL
# 28152  28153  69       lyon       LYON       lyon       Lyon  L500   LYN
# 11718  11719  31   toulouse   TOULOUSE   toulouse   Toulouse  T420   TLS
# 2049    2050   6       nice       NICE       nice       Nice  N200    NS
#
#                                                       8    9   ...     17  \
# 30437  75001-75002-75003-75004-75005-75006-75007-7500...   56  ...  21288
# 4439   13001-13002-13003-13004-13005-13006-13007-1300...   55  ...   3535
# 28152  69001-69002-69003-69004-69005-69006-69007-6900...  123  ...  10117
# 11718                31000-31100-31200-31300-31400-31500  555  ...   3734
# 2049                             06000-06100-06200-06300   88  ...   4773
#
#            18       19       20      21       22       23        24     25  \
# ...

# %% [markdown]
# ## Display 50 first results

# %%
data_frame.head(50)
# Out:
#     0  1                           2                           3   \
# 0    1  1                        ozan                        OZAN
# 1    2  1       cormoranche-sur-saone       CORMORANCHE-SUR-SAONE
# 2    3  1                   plagne-01                      PLAGNE
# 3    4  1                     tossiat                     TOSSIAT
# 4    5  1                    pouillat                    POUILLAT
# 5    6  1                     torcieu                     TORCIEU
# 6    7  1                   replonges                   REPLONGES
# 7    8  1                   corcelles                   CORCELLES
# 8    9  1                       peron                       PERON
# 9   10  1                    relevant                    RELEVANT
# 10  11  1                  chaveyriat                  CHAVEYRIAT
# 11  12  1               vaux-en-bugey               VAUX-EN-BUGEY
# 12  13  1                     maillat                     MAILLAT
# ...
